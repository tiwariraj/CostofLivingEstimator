# %%
#Read In Data
import numpy as np
import pandas as pd

food = pd.read_csv('foodcost.csv', dtype={'region':'category','market':'category'}) 
#food[['marketname', 'region']].values
#food.shape #(57, 90)
#food.head()

# %%
#food_trimmed = food.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
#food_trimmed.columns.tolist("apples_avg_col","apples_price")
#food_trimmed["apples_avg_col"]['$','£'].str.replace
#pd.melt(food, id_vars='row') pd.Series(['foo', 'fuz', np.nan]).str.replace('f', 'b')
#for col in 

food_trimmed["apples_avg_col"] = food_trimmed["apples_avg_col"].replace({'\$': '', '£': '','\xa0$':'', '€': ''}, regex=True)
#food_trimmed["apples_avg_col"] = food_trimmed["apples_avg_col"].replace({'\$': '', '£': '','\xa0$':'', '€': ''}, regex=True)

# %%
food_trimmed["apples_avg_col"].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-6945bfad1ad0> in <module>()
# ----> 1 food_trimmed["apples_avg_col"].astype('int64')
#
# ~\Anaconda2\envs\py3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# ~\Anaconda2\envs\py3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...
